# %%
gauss = [0.00030, 0.00156, 0.00444, 0.00851, 0.00153, 0.00018, 0.01307, 0.09499, 0.00579, 0.04614, 0.19991, 2.80652]
lu = [0.00001, 0.00002, 0.00003, 0.00010, 0.00019, 0.00056, 0.00148, 0.03505, 0.02898, 0.14075, 1.32477, 17.65212]
gaussNoPragma = [0.00002, 0.00000, 0.00001, 0.00003, 0.00009, 0.00033, 0.00136, 0.00645, 0.02998, 0.16445, 0.85843, 8.84454]
luNoPragma = [0.00000, 0.00000, 0.00001, 0.00003, 0.00011, 0.00042, 0.00163, 0.00787, 0.05812, 0.44895, 3.96482, 74.91179]
jacobi = [0.00939, 0.00010, 0.00013, 0.00037, 0.00003, 0.00004, 0.00278, 0.00409, 0.00277, 0.00674, 0.00315, 0.00842, 0.05343, 0.19001, 0.99603]
gaussSidel = [0.00070, 0.00017, 0.00012, 0.00013, 0.00020, 0.00054, 0.00066, 0.00138, 0.02787, 0.01441, 0.01749, 0.05593, 0.13923, 0.48564, 3.33069]
jacobiNoPragma = [0.00006, 0.00001, 0.00002, 0.00002, 0.00004, 0.00006, 0.00014, 0.00035, 0.00085, 0.00264, 0.00940, 0.04560, 0.15118, 0.57238, 8.07303]
gaussSidelNoPragma = [0.00004, 0.00001, 0.00001, 0.00001, 0.00002, 0.00005, 0.00009, 0.00025, 0.00071, 0.00235, 0.00911, 0.04373, 0.15273, 0.58575, 3.73531]
x = [ 2**i for i in range(1, 20)]

# %%
import matplotlib.pyplot as plt


plt.plot(x[:len(gauss)], gauss, marker='o')
plt.plot(x[:len(gaussNoPragma)], gaussNoPragma, marker='o')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Tempo(s)')
plt.title('Performance da Eliminação de Gauss')
plt.yscale('log')  # Set y-axis to logarithmic scale
# Fix the axis size
plt.xlim(-max(x[:len(gauss)]) * 0.1, max(x[:len(gauss)]) + max(x[:len(gauss)]) * 0.1)  # Set x-axis range with 10% padding
plt.ylim(1e-4, 1e3)  # Set y-axis range (e.g., from 0.0001 to 10)
# Add a legend to differentiate the two plots
plt.legend(['Com paralelismo', 'Sem paralelismo'])

plt.grid(True)
plt.show()

# %%
plt.plot(x[:len(lu)], lu, marker='o')
plt.plot(x[:len(luNoPragma)], luNoPragma, marker='o')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Tempo(s)')
plt.title('Performance da decomposição LU')
plt.yscale('log')  # Set y-axis to logarithmic scale
# Fix the axis size
plt.xlim(-max(x[:len(lu)]) * 0.1, max(x[:len(lu)]) + max(x[:len(lu)]) * 0.1)  # Set x-axis range with 10% padding
plt.ylim(1e-4, 1e3)  # Set y-axis range (e.g., from 0.0001 to 10)
# Add a legend to differentiate the two plots
plt.legend(['Com paralelismo', 'Sem paralelismo'])

plt.grid(True)
plt.show()

# %%
plt.plot(x[:len(jacobi)], jacobi, marker='o')
plt.plot(x[:len(jacobiNoPragma)], jacobiNoPragma, marker='o')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Tempo(s)')
plt.title('Performance do Método de Jacobi')
plt.yscale('log')  # Set y-axis to logarithmic scale
# Fix the axis size
plt.xlim(-max(x[:len(jacobi)]) * 0.1, max(x[:len(jacobi)]) + max(x[:len(jacobi)]) * 0.1)  # Set x-axis range with 10% padding
plt.ylim(1e-4, 1e3)  # Set y-axis range (e.g., from 0.0001 to 10)
# Add a legend to differentiate the two plots
plt.legend(['Com paralelismo', 'Sem paralelismo'])

plt.grid(True)
plt.show()

# %%
plt.plot(x[:len(gaussSidel)], gaussSidel, marker='o')
plt.plot(x[:len(gaussSidelNoPragma)], gaussSidelNoPragma, marker='o')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Tempo(s)')
plt.title('Performance do Método de Gauss-Seidel')
plt.yscale('log')  # Set y-axis to logarithmic scale
# Fix the axis size
plt.xlim(-max(x[:len(gaussSidelNoPragma)]) * 0.1, max(x[:len(gaussSidelNoPragma)]) + max(x[:len(gaussSidelNoPragma)]) * 0.1)  # Set x-axis range with 10% padding
plt.ylim(1e-4, 1e3)  # Set y-axis range (e.g., from 0.0001 to 10)
# Add a legend to differentiate the two plots
plt.legend(['Com paralelismo', 'Sem paralelismo'])

plt.grid(True)
plt.show()

# %%
values = [0.46266, 0.24419, 0.21519, 0.14678, 0.14688, 0.14535, 0.13978, 0.12686, 0.12117, 0.11242, 0.10835, 0.10427, 0.10544, 0.10210, 0.10828, 0.16463, 2.17700, 2.28001, 2.39551, 2.51899]
[values[i]/(i+1) for i in range(0, len(values))]
# Out:
# [0.46266,
#  0.122095,
#  0.07173,
#  0.036695,
#  0.029376000000000003,
#  0.024225,
#  0.019968571428571426,
#  0.0158575,
#  0.013463333333333334,
#  0.011242,
#  0.00985,
#  0.008689166666666666,
#  0.00811076923076923,
#  0.007292857142857143,
#  0.007218666666666667,
#  0.010289375,
#  0.12805882352941178,
#  0.1266672222222222,
#  0.12607947368421052,
#  0.1259495]

# %%
# Data for the graph
columns = list(range(1, 21))
values = [0.46266, 0.24419, 0.21519, 0.14678, 0.14688, 0.14535, 0.13978, 0.12686, 0.12117, 0.11242, 0.10835, 0.10427, 0.10544, 0.10210, 0.10828, 0.16463, 2.17700, 2.28001, 2.39551, 2.51899]
teo_values = [values[0]/(i+1) for i in range(0, len(values))]

# Plot the data
plt.plot(columns, values, marker='o')
plt.plot(columns, teo_values, marker='o')
plt.xlabel('Quantidade de Threads')
plt.ylabel('Tempo(s)')
plt.title('Gráfico para tempo de execução por quantidade de Threads numa matriz de 1024x1024')
plt.yscale('log')  # Set y-axis to logarithmic scale

# Fix the axis size
plt.xlim(-max(columns) * 0.1, max(columns) + max(columns) * 0.1)  # Set x-axis range with 10% padding
plt.ylim(0, 3)  # Set y-axis range (e.g., from 0 to 3)
plt.legend(['Emprírico', 'Teórico'])


# Add a grid
plt.grid(True)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_30946/3483511044.py:16: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, 3)  # Set y-axis range (e.g., from 0 to 3)
